# %%
import pandas as pd
import numpy as np

# %%
review = pd.read_json('../../datasets/yelp_academic_dataset_review.json', lines=True, encoding='utf-8')
# Out:
# UnicodeDecodeErrorTraceback (most recent call last)
# <ipython-input-5-05cc4ebe877a> in <module>()
# ----> 1 review = pd.read_json('../../datasets/yelp_academic_dataset_review.json', lines=True, encoding='utf-8')
#
# /home/cusp/xz1845/.conda/envs/myPy27/lib/python2.7/site-packages/pandas/io/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines)
#     273         # commas and put it in a json list to make a valid json object.
#     274         lines = list(StringIO(json.strip()))
# --> 275         json = u'[' + u','.join(lines) + u']'
#     276
#     277     obj = None
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xc3 in position 173: ordinal not in range(128)

# %%
pd.read_json?

# %%
# read the entire file into a python array
with open('../../datasets/yelp_academic_dataset_review.json', 'rb') as f:
    data = f.readlines()

# remove the trailing "\n" from each line
data = map(lambda x: x.rstrip(), data)


data_json_str = "[" + ','.join(data) + "]"

# now, load it into pandas
data_df = pd.read_json(data_json_str)

# %%
data_df
# Out:
#                     business_id  cool       date  funny  \
# 0        2aFiy99vNLklCx3T_tGS9A     0 2011-10-10      0
# 1        2aFiy99vNLklCx3T_tGS9A     0 2010-12-29      0
# 2        2aFiy99vNLklCx3T_tGS9A     0 2011-04-29      0
# 3        2LfIuF3_sX6uwe-IR-P0jQ     1 2014-07-14      0
# 4        2LfIuF3_sX6uwe-IR-P0jQ     0 2014-01-15      0
# 5        2LfIuF3_sX6uwe-IR-P0jQ     1 2013-04-28      0
# 6        2LfIuF3_sX6uwe-IR-P0jQ     0 2014-10-12      0
# 7        2LfIuF3_sX6uwe-IR-P0jQ     0 2012-09-18      0
# 8        2LfIuF3_sX6uwe-IR-P0jQ     0 2015-10-11      0
# 9        2LfIuF3_sX6uwe-IR-P0jQ     0 2015-04-05      0
# 10       2LfIuF3_sX6uwe-IR-P0jQ     0 2014-07-08      0
# 11       2LfIuF3_sX6uwe-IR-P0jQ     1 2014-08-23      1
# 12       2LfIuF3_sX6uwe-IR-P0jQ     0 2015-01-13      0
# 13       2LfIuF3_sX6uwe-IR-P0jQ     0 2014-08-05      0
# 14       2LfIuF3_sX6uwe-IR-P0jQ     1 2014-12-22      0
# 15       2LfIuF3_sX6uwe-IR-P0jQ     2 2013-11-17      3
# ...

# %%
df_t = pd.read_pickle('../Anomaly/spectural_cluster.pkl')

# %%
df_t.reset_index(inplace=True)

# %%
df_merged = df_t.merge(data_df, how='left', left_index=True, right_on='business_id')

# %%
df_merged.to_csv('../Anomaly/torronto_chi.csv', index_label=False, encoding='utf-8')

# %%
df_merged.to_csv?
