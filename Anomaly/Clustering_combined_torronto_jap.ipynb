# %%
import numpy as np
import pandas as pd
from scipy.spatial import distance
from sklearn.cluster import SpectralClustering
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_pickle('../data_processeing/Yelp_Cuisine_Japanese.pkl')
d = pd.read_pickle('../data_processeing/Yelp_Cuisine_Japanese.pkl')
df = df.loc[:,'AcceptsInsurance':'cuisine_Japanese']

# %%
if_col_keep = 1.0* df.count().sort_values() / len(df) > 0.7
col_keep = df.count().sort_values()[if_col_keep]
col_prefix = []
for c in col_keep.keys().values:
    #print c.split('_')[0]
    if c == 'cuisine_Chinese':
        pass
    else:
        col_prefix.append(c.split('_')[0])
col_prefix = list(set(col_prefix))
delete_col = ['HairSpecializesIn']
for c in delete_col:
    col_prefix.remove(c)
len(col_prefix)
col_with_prefix = []
for c in df.columns[:-1]:
    if c.split('_')[0] in col_prefix:
        col_with_prefix.append(c)
df1 = df.copy()
md = df1.join(d.review_count).review_count.median()
df1['review_count_greater_median'] = df1.join(d.review_count).review_count > md
df_basic = d[[u'categories', u'city', u'hours', u'is_open', u'latitude', u'longitude', u'name', u'neighborhood', u'postal_code', u'review_count', u'stars', u'state']]
df_final = df_basic.join(df1[col_with_prefix+['review_count_greater_median','cuisine_Japanese']])

# %%
spatial_label = pd.read_pickle('../data_processeing/spatial_labels.pkl')

# %%
df_new = pd.concat([df_final,spatial_label], axis=1)

# %%
df_select = df_new[(df_new['stars'] >= 4) & (df_new['spatial_label'] == 3) & (df_new['cuisine_Japanese'] == 2)]

# %%
df_select
# Out:
#                                                                categories  \
# LPCFfrQow0kl7EABuM7VDA       [Seafood, Japanese, Sushi Bars, Restaurants]
# abO4gvGKB0aVjsrXHlgeFg       [Japanese, Restaurants, Fish & Chips, Ramen]
# -4bPFENRdTqjML8aKEL6ow                [Sushi Bars, Restaurants, Japanese]
# CAhoEZPcAEvBSoCxn_fAjQ  [Ramen, Cafes, Sushi Bars, Japanese, Restaurants]
# 96DHi-xkBB3CtsQRTPUjxQ                [Restaurants, Sushi Bars, Japanese]
# bNHeKmkBx5emT9xLfdWyjw                [Restaurants, Sushi Bars, Japanese]
# L82O1ZFFQfjJxF0_PYWPnA       [Restaurants, Japanese, Tapas Bars, Izakaya]
# jniApOOS8ppUHhESL7OzTg           [Korean, Restaurants, Seafood, Japanese]
# Qmwfg-PtYuCo5Q_IwcA_HQ                [Japanese, Restaurants, Sushi Bars]
# H5poGfDHCDMip7VYi7u8Rg                [Sushi Bars, Restaurants, Japanese]
# 8I5U8OQ06nSxX2y4PPOWzQ                          [Restaurants, Sushi Bars]
# PUneCUDGvdgnay3uvI89fA                [Japanese, Sushi Bars, Restaurants]
# eQRopptwTiGRGOqo5RWxbg  [Event Planning & Services, Japanese, Restaura...
# G9jwU3O0HOXTHt43eJi2mg                            [Restaurants, Japanese]
# KBWLCfWyfoXMvvBOXlABlw       [Japanese, Sushi Bars, Seafood, Restaurants]
# fB-v-caPf0o3eUkp_2ua2Q  [Japanese, Specialty Food, Seafood Markets, Re...
# TAAlaXAk9sWOUXZW1-wfYQ  [Japanese, Restaurants, Bars, Lounges, Steakho...
# rjJM4xHdCKJRUpovQ-msAQ                [Japanese, Sushi Bars, Restaurants]
# 9GLN1xfck07CKfNfejKCwg  [Restaurants, Food Delivery Services, Sushi Ba...
# MNIIRlWXotubOauSksv9AQ                [Restaurants, Sushi Bars, Japanese]
# XS80QAi1aYKK5v1zmKlkwA                          [Sushi Bars, Restaurants]
# zRxKrysFBrKH76yhyVdrRA                            [Restaurants, Japanese]
# AVwE6GQmlCTAjaDbli4IKg                [Sushi Bars, Japanese, Restaurants]
# PgxjXf7enBAyzjR9ftLZ2A  [Food, Japanese, Food Delivery Services, Sushi...
# PS5ghm09F2km76m4sQNJAw             [Grocery, Food, Restaurants, Japanese]
# 2lo7N8RZOCS0DDxO6LPQhw                            [Japanese, Restaurants]
# 5kpaX40N0Mj0lx0awd9PmQ  [Steakhouses, Restaurants, Teppanyaki, Japanes...
# 4JxFc9_0epj0YJPcJy3Xsg  [Restaurants, Sushi Bars, Local Services, Dry ...
# A6bnXx1see4yZSaVVCVDyw  [Fast Food, Restaurants, Salad, Japanese, Sush...
# s4IsetnGL_dUPb_7kgCfDQ          [Restaurants, Food, Sushi Bars, Japanese]
# ...                                                                   ...
# sKIAHIGW0viQGFAMGgQ3Rg                [Sushi Bars, Japanese, Restaurants]
# aeJojBE7k6_vSGNec3Z0OQ                            [Restaurants, Japanese]
# 1b7Ma0CBJ0oDPQrFOicOqQ                [Restaurants, Japanese, Sushi Bars]
# Otncrh8MiVM4WV3-xJqQbA                  [Korean, Restaurants, Sushi Bars]
# 1ORcqQT1DUHkKEZr1NpbrA  [Soup, Japanese, Sandwiches, Caterers, Event P...
# 8Lpoyo7RHWZrHlQW2JM2wQ  [Asian Fusion, Restaurants, Japanese, Sushi Ba...
# B9AHWTeEuC2s3jOawidKkA                          [Sushi Bars, Restaurants]
# TZOiMROeIalOC_3Atb8a8A  [Japanese, Restaurants, Korean, Tapas/Small Pl...
# a93TpkEV5oyEuyiI0CqAGw                [Japanese, Restaurants, Sushi Bars]
# omwPSPE8j7jEP4mecQM8KA                            [Restaurants, Japanese]
# BlWPjh2WuvQSlmYmgFsylg                [Restaurants, Japanese, Sushi Bars]
# w5axMYWy5bcY0tiqAnYeRg                [Japanese, Restaurants, Sushi Bars]
# zaAh8JjNeDyrJXf6xNkdUQ                [Sushi Bars, Restaurants, Japanese]
# aT9jGDqTCvVjGjbYC969Rg  [Japanese, Sushi Bars, Food Court, Restaurants...
# -BbnAc9YEO6pjvJGEtFbVQ            [Ramen, Restaurants, Japanese, Noodles]
# iAxsnFs3qq0Qx1EJ1S9SoQ           [Restaurants, Nightlife, Japanese, Bars]
# v9DncDynhn7f-RBURtcSFw                          [Restaurants, Sushi Bars]
# cAj-wwzw8HhwpHDtF_zLhA                    [Restaurants, Japanese, Korean]
# ZL0L7IIfCRhBwRFFSs1Big                [Sushi Bars, Restaurants, Japanese]
# W4Dmj9Wxfq5gEALW6RUKTA                [Restaurants, Sushi Bars, Japanese]
# HKfW6AZ-lW7jwLJwNlcLLQ                            [Restaurants, Japanese]
# w5axMYWy5bcY0tiqAnYeRg       False           True               False
# zaAh8JjNeDyrJXf6xNkdUQ       False          False               False
# aT9jGDqTCvVjGjbYC969Rg       False           True               False
# -BbnAc9YEO6pjvJGEtFbVQ       False           True               False
# iAxsnFs3qq0Qx1EJ1S9SoQ       False           True               False
# v9DncDynhn7f-RBURtcSFw       False            NaN                 NaN
# cAj-wwzw8HhwpHDtF_zLhA       False          False               False
# ZL0L7IIfCRhBwRFFSs1Big       False           True               False
# W4Dmj9Wxfq5gEALW6RUKTA       False          False               False
# HKfW6AZ-lW7jwLJwNlcLLQ       False           True               False
# bzMO8LJmJtgo3KuyWGKUxA       False           True               False
# aLTpnF4xG3KA5trMilgChQ       False           True               False
# TR0-w6VoZDAdvFQiq7P2Ug        True          False               False
# qGL7Z0yVXET7GTq-mNyQmQ       False          False               False
# rA1WJvN6IULGbM0MTbbaaA       False            NaN                 NaN
# R5ZvZ97FDp2bD93CNKg-zQ       False          False               False
# bhoJYB0ArSqRe-Q82BI4vA       False           True               False
# GTwQgfi8DN23D9fMURYUdw       False           True               False
# LC7sXugc_BkKuZa2ghUhkQ       False           True               False
#
#                        RestaurantsGoodForGroups Smoking  \
# LPCFfrQow0kl7EABuM7VDA                    False    True
# abO4gvGKB0aVjsrXHlgeFg                     True    True
# -4bPFENRdTqjML8aKEL6ow                    False    True
# CAhoEZPcAEvBSoCxn_fAjQ                      NaN     NaN
# 96DHi-xkBB3CtsQRTPUjxQ                    False    True
# bNHeKmkBx5emT9xLfdWyjw                    False    True
# L82O1ZFFQfjJxF0_PYWPnA                    False   False
# jniApOOS8ppUHhESL7OzTg                    False   False
# Qmwfg-PtYuCo5Q_IwcA_HQ                    False   False
# H5poGfDHCDMip7VYi7u8Rg                    False   False
# 8I5U8OQ06nSxX2y4PPOWzQ                    False    True
# PUneCUDGvdgnay3uvI89fA                    False    True
# eQRopptwTiGRGOqo5RWxbg                    False    True
# G9jwU3O0HOXTHt43eJi2mg                    False   False
# KBWLCfWyfoXMvvBOXlABlw                      NaN     NaN
# fB-v-caPf0o3eUkp_2ua2Q                    False     NaN
# TAAlaXAk9sWOUXZW1-wfYQ                    False   False
# rjJM4xHdCKJRUpovQ-msAQ                    False    True
# 9GLN1xfck07CKfNfejKCwg                      NaN     NaN
# MNIIRlWXotubOauSksv9AQ                    False   False
# XS80QAi1aYKK5v1zmKlkwA                      NaN     NaN
# zRxKrysFBrKH76yhyVdrRA                    False   False
# AVwE6GQmlCTAjaDbli4IKg                    False    True
# PgxjXf7enBAyzjR9ftLZ2A                    False    True
# PS5ghm09F2km76m4sQNJAw                    False   False
# 2lo7N8RZOCS0DDxO6LPQhw                    False    True
# 5kpaX40N0Mj0lx0awd9PmQ                    False     NaN
# 4JxFc9_0epj0YJPcJy3Xsg                    False    True
# A6bnXx1see4yZSaVVCVDyw                    False    True
# s4IsetnGL_dUPb_7kgCfDQ                    False     NaN
# ...                                         ...     ...
# sKIAHIGW0viQGFAMGgQ3Rg                      NaN     NaN
# aeJojBE7k6_vSGNec3Z0OQ                    False   False
# 1b7Ma0CBJ0oDPQrFOicOqQ                    False   False
# Otncrh8MiVM4WV3-xJqQbA                    False    True
# 1ORcqQT1DUHkKEZr1NpbrA                      NaN     NaN
# 8Lpoyo7RHWZrHlQW2JM2wQ                    False    True
# B9AHWTeEuC2s3jOawidKkA                    False   False
# TZOiMROeIalOC_3Atb8a8A                      NaN   False
# a93TpkEV5oyEuyiI0CqAGw                    False    True
# omwPSPE8j7jEP4mecQM8KA                    False    True
# BlWPjh2WuvQSlmYmgFsylg                    False   False
# w5axMYWy5bcY0tiqAnYeRg                    False   False
# zaAh8JjNeDyrJXf6xNkdUQ                    False   False
# aT9jGDqTCvVjGjbYC969Rg                    False    True
# -BbnAc9YEO6pjvJGEtFbVQ                    False    True
# iAxsnFs3qq0Qx1EJ1S9SoQ                    False    True
# v9DncDynhn7f-RBURtcSFw                    False     NaN
# cAj-wwzw8HhwpHDtF_zLhA                    False   False
# ZL0L7IIfCRhBwRFFSs1Big                    False    True
# W4Dmj9Wxfq5gEALW6RUKTA                    False   False
# HKfW6AZ-lW7jwLJwNlcLLQ                    False    True
# bzMO8LJmJtgo3KuyWGKUxA                    False    True
# aLTpnF4xG3KA5trMilgChQ                    False    True
# TR0-w6VoZDAdvFQiq7P2Ug                    False    True
# qGL7Z0yVXET7GTq-mNyQmQ                    False   False
# rA1WJvN6IULGbM0MTbbaaA                    False     NaN
# R5ZvZ97FDp2bD93CNKg-zQ                    False    True
# bhoJYB0ArSqRe-Q82BI4vA                    False    True
# GTwQgfi8DN23D9fMURYUdw                    False    True
# LC7sXugc_BkKuZa2ghUhkQ                    False   False
#
#                        review_count_greater_median cuisine_Japanese  \
# LPCFfrQow0kl7EABuM7VDA                        True                2
# abO4gvGKB0aVjsrXHlgeFg                        True                2
# -4bPFENRdTqjML8aKEL6ow                       False                2
# CAhoEZPcAEvBSoCxn_fAjQ                       False                2
# 96DHi-xkBB3CtsQRTPUjxQ                        True                2
# bNHeKmkBx5emT9xLfdWyjw                        True                2
# L82O1ZFFQfjJxF0_PYWPnA                       False                2
# jniApOOS8ppUHhESL7OzTg                       False                2
# Qmwfg-PtYuCo5Q_IwcA_HQ                        True                2
# H5poGfDHCDMip7VYi7u8Rg                        True                2
# 8I5U8OQ06nSxX2y4PPOWzQ                        True                2
# PUneCUDGvdgnay3uvI89fA                        True                2
# eQRopptwTiGRGOqo5RWxbg                        True                2
# G9jwU3O0HOXTHt43eJi2mg                        True                2
# KBWLCfWyfoXMvvBOXlABlw                       False                2
# fB-v-caPf0o3eUkp_2ua2Q                       False                2
# TAAlaXAk9sWOUXZW1-wfYQ                       False                2
# rjJM4xHdCKJRUpovQ-msAQ                        True                2
# 9GLN1xfck07CKfNfejKCwg                       False                2
# MNIIRlWXotubOauSksv9AQ                        True                2
# XS80QAi1aYKK5v1zmKlkwA                       False                2
# zRxKrysFBrKH76yhyVdrRA                        True                2
# AVwE6GQmlCTAjaDbli4IKg                       False                2
# PgxjXf7enBAyzjR9ftLZ2A                       False                2
# PS5ghm09F2km76m4sQNJAw                       False                2
# 2lo7N8RZOCS0DDxO6LPQhw                        True                2
# 5kpaX40N0Mj0lx0awd9PmQ                       False                2
# 4JxFc9_0epj0YJPcJy3Xsg                        True                2
# A6bnXx1see4yZSaVVCVDyw                        True                2
# s4IsetnGL_dUPb_7kgCfDQ                       False                2
# ...                                            ...              ...
# sKIAHIGW0viQGFAMGgQ3Rg                       False                2
# aeJojBE7k6_vSGNec3Z0OQ                       False                2
# 1b7Ma0CBJ0oDPQrFOicOqQ                        True                2
# Otncrh8MiVM4WV3-xJqQbA                        True                2
# 1ORcqQT1DUHkKEZr1NpbrA                       False                2
# 8Lpoyo7RHWZrHlQW2JM2wQ                        True                2
# B9AHWTeEuC2s3jOawidKkA                       False                2
# TZOiMROeIalOC_3Atb8a8A                       False                2
# a93TpkEV5oyEuyiI0CqAGw                       False                2
# omwPSPE8j7jEP4mecQM8KA                        True                2
# BlWPjh2WuvQSlmYmgFsylg                       False                2
# w5axMYWy5bcY0tiqAnYeRg                        True                2
# zaAh8JjNeDyrJXf6xNkdUQ                       False                2
# aT9jGDqTCvVjGjbYC969Rg                        True                2
# -BbnAc9YEO6pjvJGEtFbVQ                        True                2
# iAxsnFs3qq0Qx1EJ1S9SoQ                        True                2
# v9DncDynhn7f-RBURtcSFw                       False                2
# cAj-wwzw8HhwpHDtF_zLhA                       False                2
# ZL0L7IIfCRhBwRFFSs1Big                       False                2
# W4Dmj9Wxfq5gEALW6RUKTA                       False                2
# HKfW6AZ-lW7jwLJwNlcLLQ                        True                2
# bzMO8LJmJtgo3KuyWGKUxA                        True                2
# aLTpnF4xG3KA5trMilgChQ                        True                2
# TR0-w6VoZDAdvFQiq7P2Ug                        True                2
# qGL7Z0yVXET7GTq-mNyQmQ                        True                2
# rA1WJvN6IULGbM0MTbbaaA                       False                2
# R5ZvZ97FDp2bD93CNKg-zQ                        True                2
# bhoJYB0ArSqRe-Q82BI4vA                        True                2
# GTwQgfi8DN23D9fMURYUdw                        True                2
# LC7sXugc_BkKuZa2ghUhkQ                       False                2
#
#                        spatial_label
# LPCFfrQow0kl7EABuM7VDA             3
# abO4gvGKB0aVjsrXHlgeFg             3
# -4bPFENRdTqjML8aKEL6ow             3
# CAhoEZPcAEvBSoCxn_fAjQ             3
# 96DHi-xkBB3CtsQRTPUjxQ             3
# bNHeKmkBx5emT9xLfdWyjw             3
# L82O1ZFFQfjJxF0_PYWPnA             3
# jniApOOS8ppUHhESL7OzTg             3
# Qmwfg-PtYuCo5Q_IwcA_HQ             3
# H5poGfDHCDMip7VYi7u8Rg             3
# 8I5U8OQ06nSxX2y4PPOWzQ             3
# PUneCUDGvdgnay3uvI89fA             3
# eQRopptwTiGRGOqo5RWxbg             3
# G9jwU3O0HOXTHt43eJi2mg             3
# KBWLCfWyfoXMvvBOXlABlw             3
# fB-v-caPf0o3eUkp_2ua2Q             3
# TAAlaXAk9sWOUXZW1-wfYQ             3
# rjJM4xHdCKJRUpovQ-msAQ             3
# 9GLN1xfck07CKfNfejKCwg             3
# MNIIRlWXotubOauSksv9AQ             3
# XS80QAi1aYKK5v1zmKlkwA             3
# zRxKrysFBrKH76yhyVdrRA             3
# AVwE6GQmlCTAjaDbli4IKg             3
# PgxjXf7enBAyzjR9ftLZ2A             3
# PS5ghm09F2km76m4sQNJAw             3
# 2lo7N8RZOCS0DDxO6LPQhw             3
# 5kpaX40N0Mj0lx0awd9PmQ             3
# 4JxFc9_0epj0YJPcJy3Xsg             3
# A6bnXx1see4yZSaVVCVDyw             3
# s4IsetnGL_dUPb_7kgCfDQ             3
# ...                              ...
# sKIAHIGW0viQGFAMGgQ3Rg             3
# aeJojBE7k6_vSGNec3Z0OQ             3
# 1b7Ma0CBJ0oDPQrFOicOqQ             3
# Otncrh8MiVM4WV3-xJqQbA             3
# 1ORcqQT1DUHkKEZr1NpbrA             3
# 8Lpoyo7RHWZrHlQW2JM2wQ             3
# B9AHWTeEuC2s3jOawidKkA             3
# TZOiMROeIalOC_3Atb8a8A             3
# a93TpkEV5oyEuyiI0CqAGw             3
# omwPSPE8j7jEP4mecQM8KA             3
# BlWPjh2WuvQSlmYmgFsylg             3
# w5axMYWy5bcY0tiqAnYeRg             3
# zaAh8JjNeDyrJXf6xNkdUQ             3
# aT9jGDqTCvVjGjbYC969Rg             3
# -BbnAc9YEO6pjvJGEtFbVQ             3
# iAxsnFs3qq0Qx1EJ1S9SoQ             3
# v9DncDynhn7f-RBURtcSFw             3
# cAj-wwzw8HhwpHDtF_zLhA             3
# ZL0L7IIfCRhBwRFFSs1Big             3
# W4Dmj9Wxfq5gEALW6RUKTA             3
# HKfW6AZ-lW7jwLJwNlcLLQ             3
# bzMO8LJmJtgo3KuyWGKUxA             3
# aLTpnF4xG3KA5trMilgChQ             3
# TR0-w6VoZDAdvFQiq7P2Ug             3
# qGL7Z0yVXET7GTq-mNyQmQ             3
# rA1WJvN6IULGbM0MTbbaaA             3
# R5ZvZ97FDp2bD93CNKg-zQ             3
# bhoJYB0ArSqRe-Q82BI4vA             3
# GTwQgfi8DN23D9fMURYUdw             3
# LC7sXugc_BkKuZa2ghUhkQ             3
#
# [212 rows x 67 columns]

# %% [markdown]
# # Spectual Clustering

# %%
X = df_select.loc[:, 'AgesAllowed': 'review_count_greater_median']
X = pd.concat([X, df_select[['stars']]], axis=1)
X['stars'] = X['stars'].apply(str)
X = pd.get_dummies(X, dummy_na=False, drop_first=True)
def true_false(x):
    if x == True:
        return 1
    else:
        return 0
X['review_count_greater_median'] = X['review_count_greater_median'].apply(true_false)

# %%
for n_clusters in range(2,5):  
    spectural_clustering = SpectralClustering(n_clusters=n_clusters, random_state=100, affinity='sigmoid').fit(X)
    labels = spectural_clustering.labels_
    print silhouette_score(X, labels, metric='cityblock')
    print list(labels).count(0)
    print list(labels).count(1)
    print list(labels).count(2)
    print list(labels).count(3)
    print list(labels).count(4)
# Out:
# 0.171551473534
# 186
# 26
# 0
# 0
# 0
# 0.0846245831412
# 150
# 49
# 13
# 0
# 0
# 0.0464318132094
# 10
# 49
# 13
# 140
# 0

# %%
spectural_clustering = SpectralClustering(n_clusters=2, random_state=999, affinity='sigmoid').fit(X)
labels_spectural = spectural_clustering.labels_

# %%
df_select.shape
# Out:
# (212, 67)

# %% [markdown]
# # KMeans

# %%
## function that gets silhouette scores for a clustering method
def get_silhouette_score(X, cluster_method, method='complete'):
    
    #Choose a range(list) of clusters I would like to try:
    range_n_clusters = range(2,10)
    
    if cluster_method == 'kmeans':
        for n_clusters in range_n_clusters: 
            km_result = KMeans(n_clusters=n_clusters, random_state=22).fit(X) # fit model
            cluster_labels = km_result.labels_

            # clustering model & clustering result to variable "cluster_labels". 
            silhouette_avg = silhouette_score(X, cluster_labels, random_state=22)
            print("For n_clusters ={},".format(n_clusters)+"{} - average silhouette_score :{}".\
                  format(cluster_method, silhouette_avg))

        
    elif cluster_method == 'gaussian_mix':
        for n_clusters in range_n_clusters: 
            gm = GaussianMixture(n_components=n_clusters, random_state=22).fit(X) # fit model
            cluster_labels = gm.predict(X)

            # clustering model & clustering result to variable "cluster_labels". 
            silhouette_avg = silhouette_score(X, cluster_labels, random_state=22)
            print("For n_clusters ={},".format(n_clusters)+"{} - average silhouette_score :{}".\
                  format(cluster_method, silhouette_avg))
        
        # res_mix_cluster.predict(X)
        
    elif cluster_method == 'hierarchical':
        # Define Z
        Z = linkage(X, method)

        for n_clusters in range_n_clusters:   
            cluster_labels=  fcluster(Z, n_clusters, criterion='maxclust') 

            silhouette_avg = silhouette_score(X, cluster_labels, random_state=22)
            print("For n_clusters ={},".format(n_clusters)+"{} - average silhouette_score :{}".\
                  format(cluster_method, silhouette_avg))

# %%
## choose the number of clusters using silhouette method
get_silhouette_score(X, 'kmeans')
# Out:
# For n_clusters =2,kmeans - average silhouette_score :0.139646702691
# For n_clusters =3,kmeans - average silhouette_score :0.129650660088
# For n_clusters =4,kmeans - average silhouette_score :0.114923490278
# For n_clusters =5,kmeans - average silhouette_score :0.115386171136
# For n_clusters =6,kmeans - average silhouette_score :0.118219736853
# For n_clusters =7,kmeans - average silhouette_score :0.112944680135
# For n_clusters =8,kmeans - average silhouette_score :0.10640220379
# For n_clusters =9,kmeans - average silhouette_score :0.0815172312234

# %%
n_clusters = 2  # number of clusters
#XX= X.ix[:, ] # hour of day data

#train the model.
km=KMeans(n_clusters=n_clusters, random_state=22).fit(X)
labels_km = km.labels_

print list(labels_km).count(0)
print list(labels_km).count(1)
# Out:
# 73
# 139

# %%
## Distance 
# KM=KMeans(n_clusters=k,random_state=9)
scor=km.fit_predict(X)

res_p=pd.DataFrame(km.transform(X))  ## distances of each data point to each cluster center!!!
res_p=pd.concat((res_p, pd.DataFrame(km.fit_predict(X))),axis=1)

res_p.columns=list(range(n_clusters))+["cluster"]
res_p.loc[:,"score"]=res_p.apply(lambda x: x[int(x["cluster"])],axis=1)
res_p.sort_values("score",ascending=False)[:5]
# Out:
#             0         1  cluster     score
# 181  3.414780  3.048289        1  3.048289
# 128  3.034579  2.816443        1  2.816443
# 175  2.959158  2.726894        1  2.726894
# 56   2.799787  2.658767        1  2.658767
# 28   2.777682  2.632936        1  2.632936

# %%
X_df = X.copy()

# %%
X_df['km'] = labels_km

# %%
X_df['distance_KM'] = res_p.score.values

# %%
## Get Anomalies
def get_anomaly(df, label_col, dist_or_likelihood, thres):
    
    df_anomalies = pd.DataFrame(columns=df.columns)
    
    clustermean = df.groupby(label_col)[dist_or_likelihood].mean()
    clusterstd = df.groupby(label_col)[dist_or_likelihood].std()
    
    for label in df[label_col].unique():
        anomaly = df[(df[label_col]==label) \
               & (abs(df[dist_or_likelihood] - clustermean[label]) / clusterstd[label] > thres)]
        
        df_anomalies = pd.concat([df_anomalies, anomaly], axis=0)
    
    return df_anomalies

# %%
## get anomalies based on kmeans distance
km_anomalies = get_anomaly(X_df, 'km', 'distance_KM', 2)

# %%
km_anomalies['distance_KM']
# Out:
# bGuxRBRKv7i1BKKfGbjxEw    2.816443
# B5JCODx4728Ce2Qca1NFHw    2.726894
# SjgeuBlgKER9yegpoxT99w    3.048289
# L82O1ZFFQfjJxF0_PYWPnA    2.551478
# QhAmKLX_0AgQe5HLxode9Q    2.586140
# 1pttL4MkpxOL6Mj2azOjVQ    2.625567
# rA1WJvN6IULGbM0MTbbaaA    2.551478
# Name: distance_KM, dtype: float64

# %% [markdown]
# # Gaussian Mixture

# %%
##### Gaussian Mixture #########

## choose the number of clusters using silhouette method
get_silhouette_score(X, 'gaussian_mix')
# Out:
# For n_clusters =2,gaussian_mix - average silhouette_score :0.0654529016065
# For n_clusters =3,gaussian_mix - average silhouette_score :0.0780903740302
# For n_clusters =4,gaussian_mix - average silhouette_score :0.113687282489
# For n_clusters =5,gaussian_mix - average silhouette_score :0.103280578979
# For n_clusters =6,gaussian_mix - average silhouette_score :0.100083297708
# For n_clusters =7,gaussian_mix - average silhouette_score :0.0998526673056
# For n_clusters =8,gaussian_mix - average silhouette_score :0.0878005301017
# For n_clusters =9,gaussian_mix - average silhouette_score :0.082884277143

# %%
k = 4
GM=GaussianMixture(n_components=k,random_state=22)
GM.fit(X)

label_gm = GM.predict(X)

# %%
print list(label_gm).count(0)
print list(label_gm).count(1)
print list(label_gm).count(2)
print list(label_gm).count(3)
print list(label_gm).count(4)
# Out:
# 34
# 55
# 99
# 24
# 0

# %% [markdown]
# # Isolation Forest

# %%
### 3) Isolation Foreset
from sklearn.ensemble import IsolationForest

# fit the model
ISF = IsolationForest(max_samples=100, random_state=22)
ISF.fit(X)

## compute anomaly score of the input. The lower, the more abnormal.
score_isf = ISF.decision_function(X)

# %%
score_isf.argmin()
# Out:
# 223

# %% [markdown]
# # KNN Distance

# %%
def dist2knn(x, nn, k):
    dist_ = []
    for i in range(len(nn)):
        dist_.append(distance.euclidean(x, nn.iloc[i,:]))
    dist_.sort()
    return sum(dist_[:k+1]) # +1: remove 0 self

# %%
dist_sum_knn = []
for i in range(len(X)):
    print '\r{}%'.format(100.0*(i+1)/len(X)),
    dist_sum_knn.append(dist2knn(X.iloc[i,:], X, 5))
# Out:
# 100.0%

# %% [markdown]
# # Output

# %%
result = pd.DataFrame(index=X.index)

# %%
result['clusters_sp'] = labels_spectural
result['clusters_km'] = labels_km
result['distance_km'] = km_anomalies['distance_KM']
result['clusters_gm'] = label_gm
result['scores_isf'] = score_isf
result['distance_knn'] = dist_sum_knn

# %%
result
# Out:
#                         clusters_sp  clusters_km  clusters_gm  scores_isf  \
# 8Lpoyo7RHWZrHlQW2JM2wQ          NaN      9.968119
# 1kqLZp0_FEMHGx-W4TjTLQ          NaN      9.414214
# gopA-Q9KWwC8BLIRDhusgg          NaN      7.706742
# ZDDzKXN_JXe7694zePRuTQ     2.782185     11.905373
# u3q_fVU-qxgoGWLPVy4nMw          NaN      5.414214
# UBKAE_miJ-lVmUqOTlI13g          NaN     10.000000
# S0Z8fKAUYTd2MKUuez-evA          NaN      8.660254
# 2SyYW8GiDZsqtPb-aCbosg          NaN      8.024580
# jhKKwn9FSwFbZsbbYi5WfQ          NaN     10.358485
# F4cIFBf8u81hKlGn0KgGCg          NaN      8.342417
# FpFRtA1tagxqh_rLFs4XFQ          NaN      9.146264
# 33IS-0QBNwRC8cXnHABpbg          NaN      7.388905
# jNiZgCwZj4CNw1noxiC8PQ          NaN      8.342417
# K2CdjES-IZDDEgetOnf0Vw          NaN     10.944272
# I8cCdp3q_5oCEykzZgPkQw          NaN     12.836233
# bzMO8LJmJtgo3KuyWGKUxA          NaN      9.464102
# mNRAFxAqL31c2Y96LEKggA          NaN      6.242641
# gtcsOodbmk4E0TulYHnlHA     3.131738     12.791902
# 0v8icS8wOOgEDiHDCOQkZQ          NaN      5.732051
# nqnVKM55nIZn8fNH1fIJPA          NaN      9.464102
# ZuZxDPtDsh-nmbLebRC8iA          NaN      6.610366
# FfmH-oEWN7K1za-o8KZQDA          NaN      8.342417
# zBd5JvFWuMGlnCYLaGsXZg          NaN      9.382332
# XIX4xuzrt3IzvjX9MtHr9g          NaN     10.867098
# u6JJojkbqVlVI4NqKsL54Q          NaN     11.157694
# _5XClj4E5VCIsEscbrrPKg          NaN     12.034027
# -yzBFD877La-RP739VxF7w          NaN     11.820605
# 9iJMGMsTK-q6W5MB1_Ny3Q          NaN      9.464102
# Q3UkgxNNInsPcUFhsQFcrg          NaN      9.936238
#
# [235 rows x 6 columns]

# %%
result.to_csv('torronto_chi_results.csv', index_label=False, encoding='utf-8' )
# Out:
#                         clusters_sp  clusters_km  clusters_gm  scores_isf
# KeQ1cK564cL5C_hBTFrqnA            0            0            2   -0.026406
# f5xm2RiwLv0gbmXU4BkrGA            0            1            4    0.036797
# q0oPX1DXW86QytTvvrD9MA            0            0            2    0.012530
# 0C6uuZBD7xKS-uucgwoyQw            0            1            1    0.026864
# mevOvXMnlTLbSl4w8fcG2A            0            0            3    0.053299
# nTQhgQZa7HhIpyM0ICC1mw            0            0            3    0.023877
# TBzgzTFSa7pJXiLD7emYaQ            0            0            3    0.015436
# 0XlbdDkYzC14SZF_bUGeXA            0            1            0    0.084316
# o5t33JVLpZWf269AEPB95Q            0            0            3    0.044613
# Ih7a0qOMLFnYAec8qyq2Gg            0            1            0    0.036159
# WpK-mZ7w-304c78MOEYH6A            0            0            3    0.036177
# E_mRnwhHLuz6tgMBScw1mw            0            0            3    0.013504
# 2BuiyGL0JbNjnc88fYH39Q            0            0            3    0.021527
# yPR8Bh55-9NXmooZS7lrLA            0            1            0    0.072260
# Q62lGVKqoKJ09lZNt2qpfw            0            0            3    0.083150
# IithJLAUG3gWcHw9EKLLFA            0            0            3    0.075042
