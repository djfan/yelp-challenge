# %% [markdown]
# To do:
#
# Can we predict the rating given a random location
#
# buffer point (road width?)
#
# accessibility (find interset with different types of roads)
#
# connectivity (near endpoint, intersection, etc.)
#
# intercity: types of urban forms

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import osmnx as ox

# %%
for i in uc02_attr.columns:
    print i
# Out:
# address
# attributes
# business_id
# categories
# city
# hours
# is_open
# latitude
# longitude
# name
# neighborhood
# postal_code
# review_count
# stars
# state
# type
# AcceptsInsurance
# AgesAllowed
# Alcohol
# Ambience_casual
# Ambience_classy
# Ambience_divey
# Ambience_hipster
# Ambience_intimate
# Ambience_romantic
# Ambience_touristy
# Ambience_trendy
# Ambience_upscale
# BYOB
# BYOBCorkage
# BestNights_friday
# BestNights_monday
# BestNights_saturday
# BestNights_sunday
# BestNights_thursday
# BestNights_tuesday
# BestNights_wednesday
# BikeParking
# BusinessAcceptsBitcoin
# BusinessAcceptsCreditCards
# BusinessParking_garage
# BusinessParking_lot
# BusinessParking_street
# BusinessParking_valet
# BusinessParking_validated
# ByAppointmentOnly
# Caters
# CoatCheck
# Corkage
# DietaryRestrictions_dairy-free
# DietaryRestrictions_gluten-free
# DietaryRestrictions_halal
# DietaryRestrictions_kosher
# DietaryRestrictions_soy-free
# DietaryRestrictions_vegan
# ...

# %%
uc02_attr = pd.read_pickle('UC02_df_uc_food_att.p')

# %%
uc02_attr.columns
# Out:
# Index([                        u'address',                      u'attributes',
#                            u'business_id',                      u'categories',
#                                   u'city',                           u'hours',
#                                u'is_open',                        u'latitude',
#                              u'longitude',                            u'name',
#                           u'neighborhood',                     u'postal_code',
#                           u'review_count',                           u'stars',
#                                  u'state',                            u'type',
#                       u'AcceptsInsurance',                     u'AgesAllowed',
#                                u'Alcohol',                 u'Ambience_casual',
#                        u'Ambience_classy',                  u'Ambience_divey',
#                       u'Ambience_hipster',               u'Ambience_intimate',
# ...

# %%
ox.plot_graph(ox.graph_from_place('Modena, Italy'))
# Out:
# (<matplotlib.figure.Figure at 0x7f288cd23990>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f2874da8150>)

# %%
ox.graph_from_place(Urbana-Champaign)

# %%
G_urbana = ox.graph_from_place('Urbana, IL')
ox.plot_graph(G_urbana)
# Out:
# (<matplotlib.figure.Figure at 0x7f6ab0522910>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f6ab0522310>)

# %%
G_urbana.edge
# Out:
# {2384814080: {2384814084: {0: {'highway': u'footway',
#     'length': 11.873003322585129,
#     'oneway': False,
#     'osmid': 229945852}},
#   2384814096: {0: {'geometry': <shapely.geometry.linestring.LineString at 0x7f6ab2c15ed0>,
#     'highway': u'footway',
#     'length': 14.470949806540769,
#     'oneway': False,
#     'osmid': 231453603}},
#   2384814101: {0: {'geometry': <shapely.geometry.linestring.LineString at 0x7f6ab2c15110>,
#     'highway': u'footway',
#     'length': 26.591818318069521,
#     'oneway': False,
#     'osmid': 231453604}}},
#  2384814084: {626693588: {0: {'highway': u'footway',
#     'length': 13.280106294946368,
#     'oneway': False,
#     'osmid': 49342711}},
#   2384814080: {0: {'highway': u'footway',
#     'length': 11.873003322585129,
#     'oneway': False,
#     'osmid': 229945852}},
#   2384814096: {0: {'highway': u'footway',
#     'length': 19.372877005926316,
#     'oneway': False,
#     'osmid': 49342711}}},
# ...

# %%
G_champaign = ox.graph_from_place('Champaign, IL')
ox.plot_graph(G_champaign)
# Out:
# (<matplotlib.figure.Figure at 0x7f6aaae3e850>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f6a93558b10>)
